# %% [markdown]
# # Pandas
# Helps in manipulate data, clean and transform it.
#
# # Numpy
# Creates a multi-dimansional array objects.
#
# # Scikit Learn
# It converts Pandas DataFrame to Numpy arrays.

# %%
import pandas as pd
import numpy as np

data= pd.read_csv("C:/Users/Dell/Desktop/Udemy_ML/Student_data .csv") #Put the path of the csv file
data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
#To view top 10 rows of the file
data.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# ...

# %%
#To view bottom 10 of the file
data.tail(10)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2382       3383   16       0          0                  3        13.941823
# 2383       3384   16       1          2                  2        11.736409
# 2384       3385   15       1          0                  1        16.655581
# 2385       3386   16       1          0                  1         1.445434
# 2386       3387   16       0          0                  2        13.814021
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
#To view the dimensionality of the data frame (rows, columns)
data.shape
# Out:
# (2392, 15)

# %%
#size = rows*columns
data.size
# Out:
# 35880

# %%
#Total number of rows
len(data)
# Out:
# 2392

# %%
#Column names
data.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
#To view/extract a particular column
data["StudentID"]
# Out:
# 0       1001
# 1       1002
# 2       1003
# 3       1004
# 4       1005
#         ...
# 2387    3388
# 2388    3389
# 2389    3390
# 2390    3391
# 2391    3392
# Name: StudentID, Length: 2392, dtype: int64

# %%
#To extract a range of rows from a column 
data["StudentID"][:6]
#first 6 rows of column
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# Name: StudentID, dtype: int64

# %%
data["StudentID"][3]
# Out:
# 1004

# %%
data[5:10]
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 5         0         0                1                1       0      0
# 6        10         0                3                0       1      0
# 7        22         1                1                1       0      0
# 8         1         0                2                0       1      0
# 9         0         0                3                1       0      0
#
#    Volunteering       GPA  GradeClass
# 5             0  3.084184         1.0
# ...

# %%
data[['StudentID', 'Age']][:5]
# Out:
#    StudentID  Age
# 0       1001   17
# 1       1002   18
# 2       1003   15
# 3       1004   17
# 4       1005   17

# %%
data.sort_values(['Age'])
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1195       2196   15       1          2                  2         8.740675
# 1527       2528   15       0          2                  2         4.745087
# 1524       2525   15       1          2                  2        18.558013
# 589        1590   15       1          0                  2        12.494013
# 590        1591   15       0          2                  2         5.650817
# ...         ...  ...     ...        ...                ...              ...
# 490        1491   18       0          0                  2        12.856041
# 487        1488   18       1          0                  1        10.007167
# 1686       2687   18       1          2                  2        17.220176
# 506        1507   18       1          0                  1        12.298060
# 1692       2693   18       0          0                  2        12.981612
#
# ...

# %%
count= data['GradeClass'].value_counts()
count.sort_values()
# Out:
# 0.0     107
# 1.0     269
# 2.0     391
# 3.0     414
# 4.0    1211
# Name: GradeClass, dtype: int64

# %%
count.plot()
# Out:
# <AxesSubplot: >

# %%
count.plot(kind = 'bar')
# Out:
# <AxesSubplot: >
